# %% [markdown]
# # Step 1: Create a database & connect to MySQL

# %%
import cursor

cursor.execute("CREATE DATABASE IF NOT EXISTS usermgmt;")
print("Database created!")

# %%
import pymysql
from dotenv import load_dotenv
import os

# Load environment variables from .env
load_dotenv()

conn = pymysql.connect(
    host=os.getenv("DB_HOST"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASS"),
    database=os.getenv("DB_NAME"),
    port=int(os.getenv("DB_PORT"))
)

cursor = conn.cursor()
print("Connection created.")
# Out:
# Connection created.

# %% [markdown]
# # Step 2: Create tables

# %%
cursor.execute("USE usermgmt;")
print("Database selected!")
# Out:
# Database selected!

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS users ( 
id INT AUTO_INCREMENT PRIMARY KEY, 
name VARCHAR(150) NOT NULL, 
email VARCHAR(255) NOT NULL UNIQUE, 
role VARCHAR(50) DEFAULT 'user' 
);

""")
conn.commit()
print("Users table created!")
# Out:
# Users table created!

# %%
cursor.execute("SHOW TABLES;")
print("Tables:", cursor.fetchall())
# Out:
# Tables: (('users',),)

# %%
from prettytable import PrettyTable

cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()
columns = [col[0] for col in cursor.description]

table = PrettyTable(columns)

for row in rows:
    table.add_row(row)

print(table)

conn.close()
# Out:
# +----+---------------+---------------------+---------+
# | id |      name     |        email        |   role  |
# +----+---------------+---------------------+---------+
# | 1  |  Aaryan Risal |  aaryan07@gmail.com |  Admin  |
# | 3  | Abiral Lamsal | abiral123@gmail.com | Manager |
# | 4  | Ujjwal Basnet | ujjwal123@gmail.com |  Viewer |
# +----+---------------+---------------------+---------+
